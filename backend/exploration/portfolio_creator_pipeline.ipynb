# %% [markdown]
# ## Pipeline flow
#
# **Get User Information -> Match Portfolio -> .... -> Optimize portfolio -> Save to Database**

# %% [markdown]
# Return values from LLM after calling match_portfolio node
#
# ```
# {
#     "name": "Coffeehouse Portfolio",
#     "allocation": {
#         "Large Cap Blend": 0.1,
#         "Large Cap Value": 0.1,
#         "Small Cap Blend": 0.1,
#         "Small Cap Value": 0.1,
#         "International Large Cap Blend": 0.1,
#         "Intermediate Bonds": 0.4,
#         "REITs": 0.1
#     },
#     "description": "Focuses on diversification across several asset classes including stocks and bonds, with a tilt towards value investing. Suitable for investors looking for a mix of growth and income with a moderate risk tolerance."
# }
# ```

# %%
import sys
import os

api_parent_dir = os.path.abspath(
    os.path.join(os.getcwd(), ".."))  # Move up twice
sys.path.append(api_parent_dir)  # Add parent of `api` to sys.path

print("Current sys.path:")
for path in sys.path:
    print(path)
# Out:
# Current sys.path:
# /Users/bryantan/.pyenv/versions/3.12.8/lib/python312.zip
# /Users/bryantan/.pyenv/versions/3.12.8/lib/python3.12
# /Users/bryantan/.pyenv/versions/3.12.8/lib/python3.12/lib-dynload
#
# /Users/bryantan/.pyenv/versions/3.12.8/envs/new_fyp_env/lib/python3.12/site-packages
# /Users/bryantan/Documents/HengOngHuat/backend

# %%
from api.utils.StockAnalyzer import StockAnalyzer
from api.constants import CATEGORY_TO_ASSET_CLASS, BOND_CATEGORIES

from yahooquery import Screener 
import pandas as pd

from typing import List, Dict, TypedDict

# %%
matched_portfolio: dict = {
    "name": "Coffeehouse Portfolio",
    "allocation": {
        "Large Cap Blend": 0.1,
        "Large Cap Value": 0.1,
        "Small Cap Blend": 0.1,
        "Small Cap Value": 0.1,
        "International Large Cap Blend": 0.1,
        "Intermediate Bonds": 0.4,
        "REITs": 0.1
    },
    "description": "Focuses on diversification across several asset classes including stocks and bonds, with a tilt towards value investing. Suitable for investors looking for a mix of growth and income with a moderate risk tolerance."
}

# matched_portfolio: dict = {
#     "name": "Swensen Portfolio",
#     "allocation": {
#         "Large Cap Blend": 0.3,
#         "International Large Cap Blend": 0.15,
#         "Emerging Markets": 0.05,
#         "Intermediate Bonds": 0.30,
#         "REITs": 0.2
#     },
#     "description": "Focuses on diversification across several asset classes including stocks and bonds, with a tilt towards value investing. Suitable for investors looking for a mix of growth and income with a moderate risk tolerance."
# }

# %%
class MatchedPortfolio(TypedDict): 
    name: str
    allocation: Dict[str, float]
    description: str

# %% [markdown]
# ## Helper methods needed

# %%
""" Pull ETFs based on allocations """
def classify_etfs(etfs: Dict[str, str]) -> Dict[str, str]:
    """
    Classify ETFs based on their category

    Args:
        etfs (dict): ETFs pulled from yfinance
        
    Returns: 
        dict: ETFs classified by asset class
    """
    classified_etfs = {}
    
    for etf, category in etfs.items():
        classified_etfs[etf] = CATEGORY_TO_ASSET_CLASS.get(category, "Other")
        
    return classified_etfs

def retrieve_etfs(limit=120) -> List[str]:
    """
    Retrieve ETFs from the Screener API
    
    Args:
        limit (int): Number of ETFs to retrieve
        
    Returns:
        list[str]: List of ETF symbols
    """
    screen = Screener()
    
    try:
        etf_data = screen.get_screeners('top_performing_etfs', count=limit)
        
        if not isinstance(etf_data, Dict):
            raise ValueError("Screener API did not return a dictionary")
        
        symbols = [
            quote["symbol"]
            for quote in etf_data.get("top_performing_etfs", {}).get("quotes", [])
        ]
        
    except Exception as e:
        print(f"Error retrieving ETFs: {e}")
        return []
    
    return symbols

def process_etf(portfolio: MatchedPortfolio, symbols: List[str]) -> Dict[str, List[str]]:
    """
    Process ETFs based on matched portfolio allocation

    Args:
        portfolio (MatchedPortfolio): Matched portfolio allocation
        symbols (List[str]): List of ETF symbols

    Returns:
        Dict[str, List[str]]: Top 10 ETFs and bond ETFs for each matched portfolio category
    """
    etf_categories = {} 
    
    for symbol in symbols:
        stock_analyzer = StockAnalyzer(symbol)
        category = stock_analyzer.asset_info.get('category', 'Others')
        etf_categories[symbol] = category
    
    mapped_etfs = classify_etfs(etf_categories)
        
    # Create filtered list with keys as categories of matched portfolio and value as empty list
    filtered_etfs = {
        category: []
        for category in portfolio['allocation'].keys()
    }
        
    # Append to filtered_etfs
    for symbol, category in mapped_etfs.items():
        if category in filtered_etfs:
            filtered_etfs[category].append(symbol)
            
    # Get the top 10 Etfs for each category
    top_10_etfs = {category: etfs[:10] for category, etfs in filtered_etfs.items() if category not in BOND_CATEGORIES}
    
    # Filter bond ETFs based on matched portfolio allocation 
    bond_etfs = {category: etfs[:10] for category, etfs in filtered_etfs.items() if category in BOND_CATEGORIES}
    
    return top_10_etfs, bond_etfs

def filter_etfs_dataframe(etf_df, bond_df):
    etf_df_filtered = etf_df.dropna(subset=[
        "Expense_Ratio", "AUM", "Average Volume", "3Y_Return", "5Y_Return", "Sharpe_1Y"])

    bond_df_filtered = bond_df.dropna(subset=[
        "Expense_Ratio", "AUM", "Average Volume", "3Y_Return", "5Y_Return", "Sharpe_1Y"])
    
    stocks_df = etf_df_filtered[
        # Stock ETFs filtering
        (etf_df_filtered["Category"] != "Intermediate Bonds") &
        (etf_df_filtered["3Y_Return"] > 0) &
        (etf_df_filtered["5Y_Return"] > 0) &
        (etf_df_filtered["AUM"] > 500_000_000)
    ]
    
    bonds_df = bond_df_filtered[
        # Bond ETFs filtering
        (bond_df_filtered["Category"] == "Intermediate Bonds") &
        # Allow slightly negative return
        (bond_df_filtered["3Y_Return"] > -0.02) &
        (bond_df_filtered["AUM"] > 500_000_000) &
        (bond_df_filtered["Expense_Ratio"] <= 0.20)
    ]
    
    # Combine stocks and bonds
    stocks_df_sorted = stocks_df.sort_values(
        by=["Sharpe_1Y", "AUM", "Average Volume"], ascending=[False, False, False]
    )

    bonds_df_sorted = bonds_df.sort_values(
        by=["Sharpe_1Y", "AUM", "Average Volume"], ascending=[False, False, False]
    )

    return stocks_df_sorted, bonds_df_sorted

def overlap_check(selected_etfs, holdings_data):
    overlap_count = {}
    
    for etf1 in selected_etfs:
        for etf2 in selected_etfs:
            if etf1 != etf2:
                common_holdings = set(holdings_data.get(etf1, [])) & set(
                    holdings_data.get(etf2, []))
                # % of overlapping holdings
                overlap_percentage = (len(common_holdings) / 10) * 100

                overlap_count[(etf1, etf2)] = overlap_percentage
                
    return overlap_count

# %% [markdown]
# ## Pipeline for portfolio creation

# %%
def pipeline():
    symbols = retrieve_etfs()
    top_10_etfs, bond_etfs = process_etf(matched_portfolio, symbols)
    
    etf_tickers = [StockAnalyzer(ticker).get_etf_metrics() for tickers in top_10_etfs.values() for ticker in tickers]
    bond_tickers = [StockAnalyzer(ticker).get_etf_metrics() for tickers in bond_etfs.values() for ticker in tickers]
    
    etf_df = pd.DataFrame([etf for etf in etf_tickers if etf])
    bond_df = pd.DataFrame([etf for etf in bond_tickers if etf])
    
    # Filter DF
    stocks_df_sorted, bonds_df_sorted = filter_etfs_dataframe(etf_df, bond_df)
    
    # Data prep for ETF holding
    selected_etfs = stocks_df_sorted["Ticker"].tolist()
    holdings_data = {etf: StockAnalyzer(etf).get_etf_holdings_top_10() for etf in selected_etfs}
   
    # Check ETF holding overlap
    overlap_count = overlap_check(selected_etfs, holdings_data)
    overlap_df = pd.DataFrame(overlap_count.items(), columns=["ETF Pair", "Overlap Percentage"])
    overlap_df = overlap_df.sort_values(by="Overlap Percentage", ascending=False)
    
    # Filter ETFs with >30% overlap
    overlapping_pairs = overlap_df[overlap_df["Overlap Percentage"] > 10]["ETF Pair"].tolist()
    filtered_etfs = set(selected_etfs)
    for etf1, etf2 in overlapping_pairs:
        if etf1 in filtered_etfs and etf2 in filtered_etfs:
            filtered_etfs.remove(etf2)
    
    final_selected_etfs = list(filtered_etfs)
    bond_etfs = bonds_df_sorted["Ticker"].tolist()
    
    return final_selected_etfs.extend(bond_etfs)

# %%
created_portfolio = pipeline()

# %%
print(created_portfolio)
# Out:
# None

# %% [markdown]
# ## Individual Function Testing

# %%
symbols = retrieve_etfs()
top_10_etfs, bond_etfs = process_etf(matched_portfolio, symbols)

etf_tickers = [StockAnalyzer(ticker).get_etf_metrics() for tickers in top_10_etfs.values() for ticker in tickers]
bond_tickers = [StockAnalyzer(ticker).get_etf_metrics() for tickers in bond_etfs.values() for ticker in tickers]

# %%
etf_df = pd.DataFrame([etf for etf in etf_tickers if etf])
bond_df = pd.DataFrame([etf for etf in bond_tickers if etf])

# %%
etf_df
# Out:
#    Ticker                                               Name            AUM  \
# 0    BBUS              JPMorgan BetaBuilders U.S. Equity ETF     4356184064
# 1    SPLG                         SPDR Portfolio S&P 500 ETF    58660720640
# 2     IVV                           iShares Core S&P 500 ETF   594077155328
# 3    ITOT       iShares Core S&P Total U.S. Stock Market ETF    65149771776
# 4    SCHX                          Schwab U.S. Large-Cap ETF    52639002624
# 5    SPTM  SPDR Portfolio S&P 1500 Composite Stock Market...     9818044416
# 6    PBUS                               Invesco MSCI USA ETF     5994743808
# 7     VOO                               Vanguard S&P 500 ETF  1399085203456
# 8      VV                      Vanguard Large Cap Index Fund    59214147584
# 0         0.110243   0.967955        0.014399
# 1         0.109972   0.986032        0.008246
# 2         0.116578   0.982043        0.007490
# 3         0.107660   0.938448        0.019746
# 4         0.131060   1.057542        0.017584
# 5         0.102682   0.974156        0.013105
# 6         0.110284   0.950899        0.037073
# 7         0.112585   0.983947        0.007542
# 8         0.113851   0.969854        0.013825
# 9         0.109547   0.962457        0.015429
# 10        0.123163   0.910222        0.077143
# 11        0.086701   0.969722        0.082244
# 12        0.076841   0.969060        0.081583
# 13        0.176557   1.006866        0.073836
# 14        0.128660   0.987530        0.087529
# 15        0.143087   0.948266        0.090839
# 16        0.078173   0.815349        0.102256
# 17        0.144603   1.010839        0.088007
# 18        0.079939   0.969066        0.081580
# 19        0.118970   0.979843        0.031802
# 20        0.036139   0.733981        0.107845
# 21        0.090377   0.858587        0.133798
# 22        0.051415   0.820243        0.132634
# 23        0.199823   0.718895        0.163473
# 24        0.105582   0.721325        0.101801
# 25        0.122887   0.728572        0.102935
# 26        0.137046   0.532850        0.154351
# 27        0.149012   0.588532        0.159261
# 28        0.141389   0.582039        0.158228

# %%
bond_df
# Out:
#   Ticker                                        Name          AUM  \
# 0    BIV  Vanguard Intermediate-Term Bond Index Fund  44127584256
#
#    Average Volume            Category  3Y_Return  5Y_Return  YTD_Return  \
# 0         1364142  Intermediate Bonds   0.004405   0.012986     2.87795
#
#    Dividend_Yield_Forward  Dividend_Yield_Trailing  3Y_Beta  Expense_Ratio  \
# 0                  0.0374                      0.0     1.06         0.0003
#
#    Turnover_Ratio 1Y_Return  1Y_Sharpe  Tracking_Error_1Y  1Y_Return_calc  \
# 0            0.55      None   0.356093           0.141507        0.098002
#
#    Sharpe_1Y  Tracking_Error
# 0  -0.500287        0.183872

# %%
stocks_df_sorted, bonds_df_sorted = filter_etfs_dataframe(etf_df, bond_df)

# %%
stocks_df_sorted
# Out:
#    Ticker                                               Name            AUM  \
# 4    SCHX                          Schwab U.S. Large-Cap ETF    52639002624
# 17    MGV                 Vanguard Mega Cap Value Index Fund     9028613120
# 13   DIVB                          iShares Core Dividend ETF      683180928
# 14    VTV               Vanguard Value Index Fund ETF Shares   195238002688
# 1    SPLG                         SPDR Portfolio S&P 500 ETF    58660720640
# 7     VOO                               Vanguard S&P 500 ETF  1399085203456
# 2     IVV                           iShares Core S&P 500 ETF   594077155328
# 19    EPS                      WisdomTree U.S. LargeCap Fund     1077484928
# 5    SPTM  SPDR Portfolio S&P 1500 Composite Stock Market...     9818044416
# 8      VV                      Vanguard Large Cap Index Fund    59214147584
# 11   IUSV                    iShares Core S&P U.S. Value ETF    20256749568
# 18   VOOV       Vanguard S&P 500 Value Index Fund ETF Shares     5711442432
# 12   SPYV                   SPDR Portfolio S&P 500 Value ETF    25841948672
# 0    BBUS              JPMorgan BetaBuilders U.S. Equity ETF     4356184064
# 9    VONE        Vanguard Russell 1000 Index Fund ETF Shares     7934553088
# 6    PBUS                               Invesco MSCI USA ETF     5994743808
# 25        0.122887   0.728572        0.102935
# 24        0.105582   0.721325        0.101801
# 27        0.149012   0.588532        0.159261
# 28        0.141389   0.582039        0.158228

# %%
bonds_df_sorted
# Out:
#   Ticker                                        Name          AUM  \
# 0    BIV  Vanguard Intermediate-Term Bond Index Fund  44127584256
#
#    Average Volume            Category  3Y_Return  5Y_Return  YTD_Return  \
# 0         1364142  Intermediate Bonds   0.004405   0.012986     2.87795
#
#    Dividend_Yield_Forward  Dividend_Yield_Trailing  3Y_Beta  Expense_Ratio  \
# 0                  0.0374                      0.0     1.06         0.0003
#
#    Turnover_Ratio 1Y_Return  1Y_Sharpe  Tracking_Error_1Y  1Y_Return_calc  \
# 0            0.55      None   0.356093           0.141507        0.098002
#
#    Sharpe_1Y  Tracking_Error
# 0  -0.500287        0.183872

# %%
# Data prep for ETF holding
selected_etfs = stocks_df_sorted["Ticker"].tolist()
holdings_data = {etf: StockAnalyzer(etf).get_etf_holdings_top_10() for etf in selected_etfs}

# %%
holdings_data
# Out:
# {'SCHX': ['Apple Inc',
#   'NVIDIA Corp',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Broadcom Inc',
#   'Berkshire Hathaway Inc Class B',
#   'Alphabet Inc Class C',
#   'Tesla Inc'],
#  'MGV': ['JPMorgan Chase & Co',
#   'Berkshire Hathaway Inc Class B',
#   'Exxon Mobil Corp',
#   'Broadcom Inc',
#   'UnitedHealth Group Inc',
#   'Walmart Inc',
#   'Procter & Gamble Co',
#   'Johnson & Johnson',
#   'The Home Depot Inc',
#   'AbbVie Inc'],
#  'DIVB': ['Cisco Systems Inc',
#   'International Business Machines Corp',
#   'Accenture PLC Class A',
#   'JPMorgan Chase & Co',
#   'Texas Instruments Inc',
#   'Exxon Mobil Corp',
#   'Wells Fargo & Co',
#   'Chevron Corp',
#   'Automatic Data Processing Inc',
#   'Verizon Communications Inc'],
#  'VTV': ['Berkshire Hathaway Inc Class B',
#   'JPMorgan Chase & Co',
#   'Exxon Mobil Corp',
#   'Broadcom Inc',
#   'UnitedHealth Group Inc',
#   'Walmart Inc',
#   'Procter & Gamble Co',
#   'Johnson & Johnson',
#   'The Home Depot Inc',
#   'AbbVie Inc'],
#  'SPLG': ['Apple Inc',
#   'NVIDIA Corp',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Berkshire Hathaway Inc Class B',
#   'Broadcom Inc',
#   'Alphabet Inc Class C',
#   'Tesla Inc'],
#  'VOO': ['Apple Inc',
#   'NVIDIA Corp',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Berkshire Hathaway Inc Class B',
#   'Broadcom Inc',
#   'Alphabet Inc Class C',
#   'Tesla Inc'],
#  'IVV': ['Apple Inc',
#   'NVIDIA Corp',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Berkshire Hathaway Inc Class B',
#   'Broadcom Inc',
#   'Alphabet Inc Class C',
#   'Tesla Inc'],
#  'EPS': ['Apple Inc',
#   'Alphabet Inc Class A',
#   'Amazon.com Inc',
#   'NVIDIA Corp',
#   'Microsoft Corp',
#   'Meta Platforms Inc Class A',
#   'JPMorgan Chase & Co',
#   'Berkshire Hathaway Inc Class B',
#   'Exxon Mobil Corp',
#   'Eli Lilly and Co'],
#  'SPTM': ['Apple Inc',
#   'NVIDIA Corp',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Berkshire Hathaway Inc Class B',
#   'Broadcom Inc',
#   'Alphabet Inc Class C',
#   'Tesla Inc'],
#  'VV': ['Apple Inc',
#   'Microsoft Corp',
#   'NVIDIA Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Broadcom Inc',
#   'Berkshire Hathaway Inc Class B',
#   'Alphabet Inc Class C',
#   'Tesla Inc'],
#  'IUSV': ['Apple Inc',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Exxon Mobil Corp',
#   'Berkshire Hathaway Inc Class B',
#   'UnitedHealth Group Inc',
#   'Procter & Gamble Co',
#   'Johnson & Johnson',
#   'JPMorgan Chase & Co',
#   'Bank of America Corp'],
#  'VOOV': ['Apple Inc',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Exxon Mobil Corp',
#   'Berkshire Hathaway Inc Class B',
#   'UnitedHealth Group Inc',
#   'Procter & Gamble Co',
#   'Johnson & Johnson',
#   'JPMorgan Chase & Co',
#   'Bank of America Corp'],
#  'SPYV': ['Apple Inc',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Exxon Mobil Corp',
#   'Berkshire Hathaway Inc Class B',
#   'UnitedHealth Group Inc',
#   'Procter & Gamble Co',
#   'Johnson & Johnson',
#   'JPMorgan Chase & Co',
#   'Bank of America Corp'],
#  'BBUS': ['Apple Inc',
#   'Microsoft Corp',
#   'NVIDIA Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Berkshire Hathaway Inc Class B',
#   'Broadcom Inc',
#   'Alphabet Inc Class C',
#   'Tesla Inc'],
#  'VONE': ['Apple Inc',
#   'Microsoft Corp',
#   'NVIDIA Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Berkshire Hathaway Inc Class B',
#   'Broadcom Inc',
#   'Alphabet Inc Class C',
#   'Tesla Inc'],
#  'PBUS': ['Apple Inc',
#   'NVIDIA Corp',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Broadcom Inc',
#   'Alphabet Inc Class C',
#   'Tesla Inc',
#   'JPMorgan Chase & Co'],
#  'VYM': ['Broadcom Inc',
#   'JPMorgan Chase & Co',
#   'Exxon Mobil Corp',
#   'Walmart Inc',
#   'Procter & Gamble Co',
#   'Johnson & Johnson',
#   'The Home Depot Inc',
#   'AbbVie Inc',
#   'Bank of America Corp',
#   'Coca-Cola Co'],
#  'ITOT': ['Apple Inc',
#   'NVIDIA Corp',
#   'Microsoft Corp',
#   'Amazon.com Inc',
#   'Meta Platforms Inc Class A',
#   'Alphabet Inc Class A',
#   'Berkshire Hathaway Inc Class B',
#   'Broadcom Inc',
#   'Alphabet Inc Class C',
#   'Tesla Inc'],
#  'ILCV': ['Apple Inc',
#   'Berkshire Hathaway Inc Class B',
#   'JPMorgan Chase & Co',
#   'Exxon Mobil Corp',
#   'UnitedHealth Group Inc',
#   'Walmart Inc',
#   'Procter & Gamble Co',
#   'Alphabet Inc Class A',
#   'Johnson & Johnson',
#   'The Home Depot Inc'],
#  'IVOV': ['Expand Energy Corp Ordinary Shares - New',
#   'Fidelity National Financial Inc',
#   'US Foods Holding Corp',
#   'Reliance Inc',
#   'Flex Ltd',
#   'W.P. Carey Inc',
#   'Unum Group',
#   'Biomarin Pharmaceutical Inc',
#   'Reinsurance Group of America Inc',
#   'Performance Food Group Co'],
#  'VBR': ['Smurfit WestRock PLC',
#   'Williams-Sonoma Inc',
#   'Atmos Energy Corp',
#   'Expand Energy Corp Ordinary Shares - New',
#   'NRG Energy Inc',
#   'First Citizens BancShares Inc Class A',
#   'Tapestry Inc',
#   'EMCOR Group Inc',
#   'Equitable Holdings Inc',
#   'F5 Inc'],
#  'SCHD': ['AbbVie Inc',
#   'Coca-Cola Co',
#   'Amgen Inc',
#   'Cisco Systems Inc',
#   'Pfizer Inc',
#   'Verizon Communications Inc',
#   'Bristol-Myers Squibb Co',
#   'Chevron Corp',
#   'Texas Instruments Inc',
#   'PepsiCo Inc'],
#  'VB': ['Smurfit WestRock PLC',
#   'Williams-Sonoma Inc',
#   'Atmos Energy Corp',
#   'Expand Energy Corp Ordinary Shares - New',
#   'NRG Energy Inc',
#   'First Citizens BancShares Inc Class A',
#   'Deckers Outdoor Corp',
#   'Liberty Formula One Group Registered Shs Series -C- Formula One',
#   'DraftKings Inc Ordinary Shares - Class A',
#   'Tapestry Inc'],
#  'IDEV': ['Novo Nordisk AS Class B',
#   'SAP SE',
#   'ASML Holding NV',
#   'Nestle SA',
#   'AstraZeneca PLC',
#   'Roche Holding AG',
#   'Novartis AG Registered Shares',
#   'HSBC Holdings PLC',
#   'Shell PLC',
#   'Lvmh Moet Hennessy Louis Vuitton SE'],
#  'VEA': ['SAP SE',
#   'Novo Nordisk AS Class B',
#   'ASML Holding NV',
#   'Nestle SA',
#   'Roche Holding AG',
#   'AstraZeneca PLC',
#   'Novartis AG Registered Shares',
#   'HSBC Holdings PLC',
#   'Toyota Motor Corp',
#   'Shell PLC'],
#  'USRT': ['Prologis Inc',
#   'Welltower Inc',
#   'Equinix Inc',
#   'Simon Property Group Inc',
#   'Digital Realty Trust Inc',
#   'Realty Income Corp',
#   'Public Storage',
#   'VICI Properties Inc Ordinary Shares',
#   'AvalonBay Communities Inc',
#   'Extra Space Storage Inc'],
#  'BBRE': ['Prologis Inc',
#   'Equinix Inc',
#   'Welltower Inc',
#   'Simon Property Group Inc',
#   'Public Storage',
#   'Realty Income Corp',
#   'Digital Realty Trust Inc',
#   'Extra Space Storage Inc',
#   'AvalonBay Communities Inc',
#   'VICI Properties Inc Ordinary Shares']}

# %%
holdings_df = pd.DataFrame.from_dict(holdings_data, orient="index").T
holdings_df
# Out:
#                              SCHX                             MGV  \
# 0                       Apple Inc             JPMorgan Chase & Co
# 1                     NVIDIA Corp  Berkshire Hathaway Inc Class B
# 2                  Microsoft Corp                Exxon Mobil Corp
# 3                  Amazon.com Inc                    Broadcom Inc
# 4      Meta Platforms Inc Class A          UnitedHealth Group Inc
# 5            Alphabet Inc Class A                     Walmart Inc
# 6                    Broadcom Inc             Procter & Gamble Co
# 7  Berkshire Hathaway Inc Class B               Johnson & Johnson
# 8            Alphabet Inc Class C              The Home Depot Inc
# 9                       Tesla Inc                      AbbVie Inc
#
#                                    DIVB                             VTV  \
# 0                     Cisco Systems Inc  Berkshire Hathaway Inc Class B
# 1  International Business Machines Corp             JPMorgan Chase & Co
# 2                 Accenture PLC Class A                Exxon Mobil Corp
# 3                   JPMorgan Chase & Co                    Broadcom Inc
# 4                 Texas Instruments Inc          UnitedHealth Group Inc
# 5                      Exxon Mobil Corp                     Walmart Inc
# 6                      Wells Fargo & Co             Procter & Gamble Co
# 7                          Chevron Corp               Johnson & Johnson
# 8         Automatic Data Processing Inc              The Home Depot Inc
# 9            Verizon Communications Inc                      AbbVie Inc
#
#                              SPLG                             VOO  \
# 0                       Apple Inc                       Apple Inc
# 1                     NVIDIA Corp                     NVIDIA Corp
# 2                  Microsoft Corp                  Microsoft Corp
# 3                  Amazon.com Inc                  Amazon.com Inc
# 4      Meta Platforms Inc Class A      Meta Platforms Inc Class A
# 5            Alphabet Inc Class A            Alphabet Inc Class A
# 6  Berkshire Hathaway Inc Class B  Berkshire Hathaway Inc Class B
# 7                    Broadcom Inc                    Broadcom Inc
# 8            Alphabet Inc Class C            Alphabet Inc Class C
# 9                       Tesla Inc                       Tesla Inc
#
#                               IVV                             EPS  \
# 0                       Apple Inc                       Apple Inc
# 1                     NVIDIA Corp            Alphabet Inc Class A
# 2                  Microsoft Corp                  Amazon.com Inc
# 3                  Amazon.com Inc                     NVIDIA Corp
# 4      Meta Platforms Inc Class A                  Microsoft Corp
# 5            Alphabet Inc Class A      Meta Platforms Inc Class A
# 6  Berkshire Hathaway Inc Class B             JPMorgan Chase & Co
# 7                    Broadcom Inc  Berkshire Hathaway Inc Class B
# 8            Alphabet Inc Class C                Exxon Mobil Corp
# 9                       Tesla Inc                Eli Lilly and Co
#
#                              SPTM                              VV  ...  \
# 0                       Apple Inc                       Apple Inc  ...
# 1                     NVIDIA Corp                  Microsoft Corp  ...
# 2                  Microsoft Corp                     NVIDIA Corp  ...
# 3                  Amazon.com Inc                  Amazon.com Inc  ...
# 4      Meta Platforms Inc Class A      Meta Platforms Inc Class A  ...
# 5            Alphabet Inc Class A            Alphabet Inc Class A  ...
# 6  Berkshire Hathaway Inc Class B                    Broadcom Inc  ...
# 7                    Broadcom Inc  Berkshire Hathaway Inc Class B  ...
# 8            Alphabet Inc Class C            Alphabet Inc Class C  ...
# 9                       Tesla Inc                       Tesla Inc  ...
#
#                              ITOT                            ILCV  \
# 0                       Apple Inc                       Apple Inc
# 1                     NVIDIA Corp  Berkshire Hathaway Inc Class B
# 2                  Microsoft Corp             JPMorgan Chase & Co
# 3                  Amazon.com Inc                Exxon Mobil Corp
# 4      Meta Platforms Inc Class A          UnitedHealth Group Inc
# 5            Alphabet Inc Class A                     Walmart Inc
# 6  Berkshire Hathaway Inc Class B             Procter & Gamble Co
# 7                    Broadcom Inc            Alphabet Inc Class A
# 8            Alphabet Inc Class C               Johnson & Johnson
# 9                       Tesla Inc              The Home Depot Inc
#
#                                        IVOV  \
# 0  Expand Energy Corp Ordinary Shares - New
# 1           Fidelity National Financial Inc
# 2                     US Foods Holding Corp
# 3                              Reliance Inc
# 4                                  Flex Ltd
# 5                            W.P. Carey Inc
# 6                                Unum Group
# 7               Biomarin Pharmaceutical Inc
# 8          Reinsurance Group of America Inc
# 9                 Performance Food Group Co
#
#                                         VBR                        SCHD  \
# 0                      Smurfit WestRock PLC                  AbbVie Inc
# 1                       Williams-Sonoma Inc                Coca-Cola Co
# 2                         Atmos Energy Corp                   Amgen Inc
# 3  Expand Energy Corp Ordinary Shares - New           Cisco Systems Inc
# 4                            NRG Energy Inc                  Pfizer Inc
# 5     First Citizens BancShares Inc Class A  Verizon Communications Inc
# 6                              Tapestry Inc     Bristol-Myers Squibb Co
# 7                           EMCOR Group Inc                Chevron Corp
# 8                    Equitable Holdings Inc       Texas Instruments Inc
# 9                                    F5 Inc                 PepsiCo Inc
#
#                                                   VB  \
# 0                               Smurfit WestRock PLC
# 1                                Williams-Sonoma Inc
# 2                                  Atmos Energy Corp
# 3           Expand Energy Corp Ordinary Shares - New
# 4                                     NRG Energy Inc
# 5              First Citizens BancShares Inc Class A
# 6                               Deckers Outdoor Corp
# 7  Liberty Formula One Group Registered Shs Serie...
# 8           DraftKings Inc Ordinary Shares - Class A
# 9                                       Tapestry Inc
#
#                                   IDEV                            VEA  \
# 0              Novo Nordisk AS Class B                         SAP SE
# 1                               SAP SE        Novo Nordisk AS Class B
# 2                      ASML Holding NV                ASML Holding NV
# 3                            Nestle SA                      Nestle SA
# 4                      AstraZeneca PLC               Roche Holding AG
# 5                     Roche Holding AG                AstraZeneca PLC
# 6        Novartis AG Registered Shares  Novartis AG Registered Shares
# 7                    HSBC Holdings PLC              HSBC Holdings PLC
# 8                            Shell PLC              Toyota Motor Corp
# 9  Lvmh Moet Hennessy Louis Vuitton SE                      Shell PLC
#
#                                   USRT                                 BBRE
# 0                         Prologis Inc                         Prologis Inc
# 1                        Welltower Inc                          Equinix Inc
# 2                          Equinix Inc                        Welltower Inc
# 3             Simon Property Group Inc             Simon Property Group Inc
# 4             Digital Realty Trust Inc                       Public Storage
# 5                   Realty Income Corp                   Realty Income Corp
# 6                       Public Storage             Digital Realty Trust Inc
# 7  VICI Properties Inc Ordinary Shares              Extra Space Storage Inc
# 8            AvalonBay Communities Inc            AvalonBay Communities Inc
# 9              Extra Space Storage Inc  VICI Properties Inc Ordinary Shares
#
# [10 rows x 27 columns]

# %%
 # Check ETF holding overlap
overlap_count = overlap_check(selected_etfs, holdings_data)
overlap_df = pd.DataFrame(overlap_count.items(), columns=["ETF Pair", "Overlap Percentage"])
overlap_df = overlap_df.sort_values(by="Overlap Percentage", ascending=False)

# %%
overlap_df
# Out:
#          ETF Pair  Overlap Percentage
# 351  (BBUS, VONE)               100.0
# 79     (VTV, MGV)               100.0
# 163   (IVV, SPTM)               100.0
# 164     (IVV, VV)               100.0
# 168   (IVV, BBUS)               100.0
# ..            ...                 ...
# 361   (BBUS, VEA)                 0.0
# 360  (BBUS, IDEV)                 0.0
# 359    (BBUS, VB)                 0.0
# 358  (BBUS, SCHD)                 0.0
# 387   (VONE, VEA)                 0.0
#
# [702 rows x 2 columns]

# %%
# Filter ETFs with >30% overlap
overlapping_pairs = overlap_df[overlap_df["Overlap Percentage"] > 30]["ETF Pair"].tolist()
filtered_etfs = set(selected_etfs)
for etf1, etf2 in overlapping_pairs:
    if etf1 in filtered_etfs and etf2 in filtered_etfs:
        filtered_etfs.remove(etf2)

final_selected_etfs = list(filtered_etfs)

# %%
final_selected_etfs
# Out:
# ['IDEV', 'EPS', 'VYM', 'USRT', 'VB', 'IVOV', 'SCHD']
